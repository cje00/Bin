# %% [markdown]
# # 지도를 이용한 데이터 시각화 하기
# * folium 라이브러리 활용
# * 지도에 표시하기 위한 정보 - 위도, 경도

# %%
import folium

# %%
folium.__version__
# Out:
# '0.12.1.post1'

# %% [markdown]
# ## 지도 띄우기
# * Map() 함수 사용

# %%
# https://www.google.com/maps/place/4%EC%B0%A8%EC%82%B0%EC%97%85%ED%98%81%EB%AA%85+%EC%B2%B4%ED%97%98%EC%84%BC%ED%84%B0/data=!4m5!3m4!1s0x0:0x6f388071e0f158d5!8m2!3d37.5544988!4d127.0404364
# 37.5544988!4d127.0404364 구글지도에서 주소창의 끝부분의 값을 참고하기
# 구글지도에서 ! 앞 & ? 앞이 위도 경도
m = folium.Map(location=[37.5544988,127.0404364])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1edbcdf4fe0400f09de19f6c0c399280 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1edbcdf4fe0400f09de19f6c0c399280&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1edbcdf4fe0400f09de19f6c0c399280 = L.map(
#                 &quot;map_1edbcdf4fe0400f09de19f6c0c399280&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa0ca85f72072992ec934171998b5dca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1edbcdf4fe0400f09de19f6c0c399280);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 확대하기 (zoom_start 옵션 사용)
m = folium.Map(location = [37.5544988, 127.0404364], zoom_start = 18)     # zoom_start=18 is the max zoom   FYI -> https://stackoverflow.com/questions/64648878/is-there-a-way-to-increase-the-zoom-on-layers-above-18-with-folium
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6b80e101db71654da00bea0dc240c27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6b80e101db71654da00bea0dc240c27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c6b80e101db71654da00bea0dc240c27 = L.map(
#                 &quot;map_c6b80e101db71654da00bea0dc240c27&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_112598040014a855b10e222004b0f183 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c6b80e101db71654da00bea0dc240c27);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도테마 설정하기 (title = '')
# OpenStreetMap(기본테마), Stamen Terrain, Stamen Toner, cartodb positron
m = folium.Map(location = [37.5544988, 127.0404364], zoom_start = 16, tiles='cartodb positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d61d6e5e0764a34654174048d843d755 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d61d6e5e0764a34654174048d843d755&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d61d6e5e0764a34654174048d843d755 = L.map(
#                 &quot;map_d61d6e5e0764a34654174048d843d755&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05ea87112f46d2e10b6bb8f6c82c4f0d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d61d6e5e0764a34654174048d843d755);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 지도에 Marker 표시하기
# * popup : 마우스 클릭시 표시되는 문구
# * icon : 표시할 아이콘 지정
# * tooltip : 마우스 오버시 표시되는 문구

# %%
m = folium.Map(location=[37.5544988, 127.0404364], zoom_start = 12)

# 성동 4차산업혁명체험센터
folium.Marker(location = [37.5544988, 127.0404364],
              icon=folium.Icon(color = 'red', icon = 'heart'),
              popup = '성동 4차산업혁명체험센터'
              ).add_to(m)

# !3d37.5435494!4d127.0189517
# 37.5435494!4d127.0189517
# 우리집
folium.Marker(location = [37.5435494, 127.0189517],
              icon = folium.Icon(color = 'red', icon='flag'),
              popup = '우리집'
              ).add_to(m)


# 37.5264068!4d126.8604559
# 양천구평생학습관스마트창의센터
folium.Marker(location = [37.5264068, 126.8604559],
              icon = folium.Icon (color='red', icon='screenshot'),
              popup = '양천구평생학습관스마트창의센터'
              ).add_to(m)

# !3d37.4994937!4d127.026378
# dental clinic
folium.Marker(location = [37.4994937, 127.026378],
              icon = folium.Icon(color='red', icon='glyphicon-tower'),
              popup="강남레옹치과"
              ).add_to(m)

# !3d37.552925!4d126.981414
# library namsan
folium.Marker(location=[37.552925, 126.981414],
              icon=folium.Icon(color='red', icon='pencil'),
              popup='남산도서관'
              ).add_to(m)

# !3d37.5591681!4d127.0349267
# library sungdong
folium.Marker(location=[37.5591681, 127.0349267],
              icon=folium.Icon(color='red', icon='pencil'),
              popup='성동구립도서관'
              ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9b6a2226f5d6e23862b69aec26bba43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9b6a2226f5d6e23862b69aec26bba43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e9b6a2226f5d6e23862b69aec26bba43 = L.map(
#                 &quot;map_e9b6a2226f5d6e23862b69aec26bba43&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e11971085fbddf817f368563b105491 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9b6a2226f5d6e23862b69aec26bba43);
#
#
#             var marker_4702ed33adef479b0d9910fe9ae372ba = L.marker(
#                 [37.5544988, 127.0404364],
#                 {}
#             ).addTo(map_e9b6a2226f5d6e23862b69aec26bba43);
#
#
#             var icon_11c5456083841ec85969b3414617a76e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4702ed33adef479b0d9910fe9ae372ba.setIcon(icon_11c5456083841ec85969b3414617a76e);
#
#
#         var popup_1465c306e31901920ade3fa837fccd50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0c9cee0a7df866aba91e20c2cc7bf4d2 = $(`&lt;div id=&quot;html_0c9cee0a7df866aba91e20c2cc7bf4d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성동 4차산업혁명체험센터&lt;/div&gt;`)[0];
#             popup_1465c306e31901920ade3fa837fccd50.setContent(html_0c9cee0a7df866aba91e20c2cc7bf4d2);
#
#
#         marker_4702ed33adef479b0d9910fe9ae372ba.bindPopup(popup_1465c306e31901920ade3fa837fccd50)
#         ;
#
#
#
#
#             var marker_ccafa4d1809a3972597beed0363efca8 = L.marker(
#                 [37.5435494, 127.0189517],
#                 {}
#             ).addTo(map_e9b6a2226f5d6e23862b69aec26bba43);
#
#
#             var icon_15729d91353d1a096f5283bfbc4db191 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ccafa4d1809a3972597beed0363efca8.setIcon(icon_15729d91353d1a096f5283bfbc4db191);
#
#
#         var popup_df906995b4727c741e534b46b4a3875d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_964077d4776af392b6010022bb8c7d1b = $(`&lt;div id=&quot;html_964077d4776af392b6010022bb8c7d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;우리집&lt;/div&gt;`)[0];
#             popup_df906995b4727c741e534b46b4a3875d.setContent(html_964077d4776af392b6010022bb8c7d1b);
#
#
#         marker_ccafa4d1809a3972597beed0363efca8.bindPopup(popup_df906995b4727c741e534b46b4a3875d)
#         ;
#
#
#
#
#             var marker_1842b6d45717b1144e48d2422098750e = L.marker(
#                 [37.5264068, 126.8604559],
#                 {}
#             ).addTo(map_e9b6a2226f5d6e23862b69aec26bba43);
#
#
#             var icon_8437f2bedc8a3ec5898aef9c56cb2c7c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;screenshot&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1842b6d45717b1144e48d2422098750e.setIcon(icon_8437f2bedc8a3ec5898aef9c56cb2c7c);
#
#
#         var popup_d752d51729bccc24d0d169a7032f3342 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9d0a86d39210f1b470d9bce76893b42a = $(`&lt;div id=&quot;html_9d0a86d39210f1b470d9bce76893b42a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;양천구평생학습관스마트창의센터&lt;/div&gt;`)[0];
#             popup_d752d51729bccc24d0d169a7032f3342.setContent(html_9d0a86d39210f1b470d9bce76893b42a);
#
#
#         marker_1842b6d45717b1144e48d2422098750e.bindPopup(popup_d752d51729bccc24d0d169a7032f3342)
#         ;
#
#
#
#
#             var marker_fc82809d4fa3aa8ad374e1571d31d5b1 = L.marker(
#                 [37.4994937, 127.026378],
#                 {}
#             ).addTo(map_e9b6a2226f5d6e23862b69aec26bba43);
#
#
#             var icon_fafcf06ec7379f2cbd3433ed88d3b5e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-tower&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc82809d4fa3aa8ad374e1571d31d5b1.setIcon(icon_fafcf06ec7379f2cb

# %% [markdown]
# ## CircleMarker(서클마커) 표시하기

# %%
# cf. 반지름 radius (pl. radii), 지름 diameter

# %%
m = folium.Map(location=[37.5544988, 127.0404364], zoom_start = 15)

# 성동 4차산업혁명체험센터
folium.Marker(location =[37.5544988, 127.0404364], 
              icon=folium.Icon(color='red', icon='heart'),
              popup='성동 4차산업혁명체험센터',
              ).add_to(m)

folium.CircleMarker(
    location = [37.5544988, 127.0404364],
    radius = 100, 
    fill = True,
    color = 'Blue',
    fill_color = '#ff3366'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ccf3a259a5d705a1f20d91fcdc94b8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ccf3a259a5d705a1f20d91fcdc94b8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8ccf3a259a5d705a1f20d91fcdc94b8f = L.map(
#                 &quot;map_8ccf3a259a5d705a1f20d91fcdc94b8f&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_487a1f7aec9cb932268d8c41f84bd576 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ccf3a259a5d705a1f20d91fcdc94b8f);
#
#
#             var marker_05b0b56f8abf95302f9846c7b893f8fe = L.marker(
#                 [37.5544988, 127.0404364],
#                 {}
#             ).addTo(map_8ccf3a259a5d705a1f20d91fcdc94b8f);
#
#
#             var icon_90e1ae759e06e07fedf7d3973f9dd1d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_05b0b56f8abf95302f9846c7b893f8fe.setIcon(icon_90e1ae759e06e07fedf7d3973f9dd1d6);
#
#
#         var popup_d8949ba6e4ed715414e98bda1e7221fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b38be9e70e982c026afeb11e6a54c13d = $(`&lt;div id=&quot;html_b38be9e70e982c026afeb11e6a54c13d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성동 4차산업혁명체험센터&lt;/div&gt;`)[0];
#             popup_d8949ba6e4ed715414e98bda1e7221fe.setContent(html_b38be9e70e982c026afeb11e6a54c13d);
#
#
#         marker_05b0b56f8abf95302f9846c7b893f8fe.bindPopup(popup_d8949ba6e4ed715414e98bda1e7221fe)
#         ;
#
#
#
#
#             var circle_marker_727d4e9c38c79997824b8c48ea03c9ac = L.circleMarker(
#                 [37.5544988, 127.0404364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff3366&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ccf3a259a5d705a1f20d91fcdc94b8f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# (Ref.) Color information
# * #FF3366 (or 0xFF3366) is unknown color: approx Radical Red. HEX triplet: FF, 33 and 66. RGB value is (255,51,102). Sum of RGB (Red+Green+Blue) = 255+51+102=408 (54% of max value = 765). Red value is 255 (100% from 255 or 62.5% from 408); Green value is 51 (20.31% from 255 or 12.5% from 408); Blue value is 102 (40.23% from 255 or 25% from 408); Max value from RGB is 255 - color contains mainly: red. Hex color #FF3366 is a web safe color. Inversed color of #FF3366 is #00CC99. Grayscale: #757575. Windows color (decimal): -52378 or 6697983. OLE color: 6697983\
# https://www.htmlcsscolor.com/hex/FF3366

# %% [markdown]
# ## 성동구 CCTV 위치를 지도로 나타내기

# %% [markdown]
# * 서울 열린데이터 광장\
# https://data.seoul.go.kr/
#
# * 성동구 cctv  -> 서울시 성동구 (안심이) CCTV 설치 현황\
# https://data.seoul.go.kr/dataList/datasetTotalList.do   \
#   --> sheet \
# https://data.seoul.go.kr/dataList/OA-20927/S/1/datasetView.do   \
#   --> 내려받기(csv)  \
# 서울시 성동구 (안심이) CCTV 설치 현황.csv  \
#   --> 세션 저장소에 업로드  \
#   (ref.) 윈도우에서 다운 받은 csv 파일의 encoding은 주로 cp-949  // utf-8, euc-kr

# %%
import pandas as pd

df = pd.read_csv('서울시 성동구 (안심이) CCTV 설치 현황.csv', encoding ='cp949')  # utf-8, euc-kr  / 윈도우에서 다운 받은 csv 파일의 encoding은 주로 cp-949
df.head()
# Out:
#    자치구                        안심 주소 CCTV 용도         위도          경도  CCTV 수량  \
# 0  성동구           G044_(고정2)6_골목길(동)    미세먼지  37.534733  127.056801        1
# 1  성동구         **C362_(회전)_성수동1가 95    미세먼지  37.539028  127.047371        1
# 2  성동구             G049_(고정2)3_자그마치    미세먼지  37.543083  127.055290        1
# 3  성동구  ***C232_(회전)_성수1가1동 656-318    미세먼지  37.545624  127.045738        1
# 4  성동구          G010_(고정2)3_성수동갈비골목    미세먼지  37.547321  127.042847        1
#
#         수정 일시
# 0  2021-12-07
# 1  2021-12-07
# 2  2021-12-07
# 3  2021-12-07
# 4  2021-12-07

# %%
df
# Out:
#       자치구                           안심 주소 CCTV 용도         위도          경도  \
# 0     성동구              G044_(고정2)6_골목길(동)    미세먼지  37.534733  127.056801
# 1     성동구            **C362_(회전)_성수동1가 95    미세먼지  37.539028  127.047371
# 2     성동구                G049_(고정2)3_자그마치    미세먼지  37.543083  127.055290
# 3     성동구     ***C232_(회전)_성수1가1동 656-318    미세먼지  37.545624  127.045738
# 4     성동구             G010_(고정2)3_성수동갈비골목    미세먼지  37.547321  127.042847
# ...   ...                             ...     ...        ...         ...
# 1251  성동구     D034_(회전)_용답동 180 전농천하천위기관리    치수방재  37.561694  127.055472
# 1252  성동구             D014_(회전)_용답꽃공원앞-04    치수방재  37.562015  127.055604
# 1253  성동구      D032_(회전)_사근동 235-12 사근사거리    치수방재  37.562175  127.049247
# 1254  성동구           D025_(회전)_용답길 86용답육갑문    치수방재  37.562283  127.050692
# 1255  성동구  D036_(회전)_천호대로 342(성동구견인차량보관소)    치수방재  37.562380  127.055765
#
#       CCTV 수량       수정 일시
# 0           1  2021-12-07
# 1           1  2021-12-07
# 2           1  2021-12-07
# 3           1  2021-12-07
# 4           1  2021-12-07
# ...       ...         ...
# 1251        1  2021-12-07
# 1252        1  2021-12-07
# 1253        1  2021-12-07
# 1254        1  2021-12-07
# 1255        1  2021-12-07
#
# [1256 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구      1256 non-null   object
#  1   안심 주소    1256 non-null   object
#  2   CCTV 용도  1256 non-null   object
#  3   위도       1256 non-null   float64
#  4   경도       1256 non-null   float64
#  5   CCTV 수량  1256 non-null   int64
#  6   수정 일시    1256 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 68.8+ KB

# %%
df.columns
# Out:
# Index(['자치구', '안심 주소', 'CCTV 용도', '위도', '경도', 'CCTV 수량', '수정 일시'], dtype='object')

# %%
# 지도에 cctv 위치 표시하기
import folium 

m = folium.Map(location = [37.5544988, 127.0404364], zoom_start = 15)

for i in range(len(df)):
  folium.Marker(location = [df.위도[i], df.경도[i]],
                icon = folium.Icon(color = 'blue', icon = 'flag'),
                popup = df['안심 주소'][i],
                ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f51efd499118005595db4a2211e37391 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f51efd499118005595db4a2211e37391&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f51efd499118005595db4a2211e37391 = L.map(
#                 &quot;map_f51efd499118005595db4a2211e37391&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_662f0c098ac844c1f3e990e7f1b9eea8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f51efd499118005595db4a2211e37391);
#
#
#             var marker_8266d953786ba19f0e6b1a7f80743724 = L.marker(
#                 [37.53473282, 127.0568008],
#                 {}
#             ).addTo(map_f51efd499118005595db4a2211e37391);
#
#
#             var icon_4296b105b74013e63db6e21c1ef0810a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8266d953786ba19f0e6b1a7f80743724.setIcon(icon_4296b105b74013e63db6e21c1ef0810a);
#
#
#         var popup_55e07b247ffe219d1dcb526df52caa75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dacff1f89957a0b3769c778ab5d252a0 = $(`&lt;div id=&quot;html_dacff1f89957a0b3769c778ab5d252a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;G044_(고정2)6_골목길(동)&lt;/div&gt;`)[0];
#             popup_55e07b247ffe219d1dcb526df52caa75.setContent(html_dacff1f89957a0b3769c778ab5d252a0);
#
#
#         marker_8266d953786ba19f0e6b1a7f80743724.bindPopup(popup_55e07b247ffe219d1dcb526df52caa75)
#         ;
#
#
#
#
#             var marker_34497ed2a563c45931abed20fc0cf667 = L.marker(
#                 [37.53902817, 127.0473709],
#                 {}
#             ).addTo(map_f51efd499118005595db4a2211e37391);
#
#
#             var icon_2048c3426476a4820566e27043fe28d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34497ed2a563c45931abed20fc0cf667.setIcon(icon_2048c3426476a4820566e27043fe28d0);
#
#
#         var popup_772226e478255909aca6d648d4eeb853 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_54c13007c56a09d7c08dc2b1ab1ac5e7 = $(`&lt;div id=&quot;html_54c13007c56a09d7c08dc2b1ab1ac5e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;**C362_(회전)_성수동1가 95&lt;/div&gt;`)[0];
#             popup_772226e478255909aca6d648d4eeb853.setContent(html_54c13007c56a09d7c08dc2b1ab1ac5e7);
#
#
#         marker_34497ed2a563c45931abed20fc0cf667.bindPopup(popup_772226e478255909aca6d648d4eeb853)
#         ;
#
#
#
#
#             var marker_b15b786aac9d7ff2198e76c42443d7f8 = L.marker(
#                 [37.54308319, 127.0552902],
#                 {}
#             ).addTo(map_f51efd499118005595db4a2211e37391);
#
#
#             var icon_7f6ca994584291095bb38fd3852c6174 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b15b786aac9d7ff2198e76c42443d7f8.setIcon(icon_7f6ca994584291095bb38fd3852c6174);
#
#
#         var popup_b94eb9f804d1a7b5d6f68ac65b5c513c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d847381ecc23d6b8642806bcc042aadc = $(`&lt;div id=&quot;html_d847381ecc23d6b8642806bcc042aadc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;G049_(고정2)3_자그마치&lt;/div&gt;`)[0];
#             popup_b94eb9f804d1a7b5d6f68ac65b5c513c.setContent(html_d847381ecc23d6b8642806bcc042aadc);
#
#
#         marker_b15b786aac9d7ff2198e76c42443d7f8.bindPopup(popup_b94eb9f804d1a7b5d6f68ac65b5c513c)
#         ;
#
#
#
#
#             var marker_c5bb2411dd0d4bad0fda190081e9eb2a = L.marker(
#                 [37.54562378, 127.0457382],
#                 {}
#             ).addTo(map_f51efd499118005595db4a2211e37391);
#
#
#             var icon_b4398c6510a993bb883fd4d0f6e4b90d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c5bb2411dd0d4bad0fda190081e9eb2a.setIcon(icon_b43

# %%
df.sample(10)
# Out:
#      자치구                             안심 주소 CCTV 용도         위도          경도  \
# 397  성동구               C786_(고정2)9_성답교회 뒷길    도심공원  37.549351  127.033913
# 434  성동구  C852_(고정3)1_성수아이파크 아파트_송정동 75-20    도심공원  37.550015  127.057014
# 107  성동구    C589_(고정2)1_리도엘리펀트_성덕정9가길 26-1    도심공원  37.539104  127.052834
# 279  성동구   C353_(고정1)7_중앙하이츠빌_성수동1가 13-472    도심공원  37.547009  127.050179
# 744  성동구  C425_(영상비상벨)7_한마음정육점_무학봉 15가길 13    도심공원  37.561486  127.029957
# 361  성동구       C229_(고정2)4_치과의사협회_광나루로 297    도심공원  37.548718  127.062248
# 551  성동구            C247_(고정2)6_금호2.3가주민센터    도심공원  37.553833  127.019051
# 542  성동구                  F057_(고정4)6_금호고교    도심공원  37.553646  127.022346
# 293  성동구                 C016_(고정3)9_화단삼거리    도심공원  37.547291  127.017113
# 811  성동구                C672_(고정2)4_블루빌아파트    도심공원  37.563049  127.028427
#
#      CCTV 수량       수정 일시
# 397        1  2021-12-07
# 434        1  2021-12-07
# 107        1  2021-12-07
# 279        1  2021-12-07
# 744        1  2021-12-07
# 361        1  2021-12-07
# 551        1  2021-12-07
# 542        1  2021-12-07
# 293        1  2021-12-07
# 811        1  2021-12-07

# %%
# CCTV 용도의 값을 중복 없이 추출해 보기
df['CCTV 용도'].unique()
# Out:
# array(['미세먼지', '도심공원', '불법주정차', '쓰레기 무단투기', '자전거보관소', '치수방재'],
#       dtype=object)

# %%
# 불법주정차 단속용 CCTV 데이터만 추출
df_car = df[df['CCTV 용도'] =='불법주정차']
df_car
# Out:
#       자치구                             안심 주소 CCTV 용도         위도          경도  \
# 991   성동구       P061_(고정4)7_천지인한의원_성덕정길 106   불법주정차  37.537220  127.055290
# 992   성동구    P035_(고정3)3_성수119안전센터_뚝섬로17길 3   불법주정차  37.537746  127.059616
# 993   성동구          P058_(고정3)4_선출빌딩_성덕정길 75   불법주정차  37.538063  127.051666
# 994   성동구         P062_(고정4)7_성원중학교_뚝섬로 400   불법주정차  37.538720  127.054907
# 995   성동구           P044_(회전)_성수동2가 혜미슈퍼 주변   불법주정차  37.541283  127.059441
# ...   ...                               ...     ...        ...         ...
# 1089  성동구         P071_(고정2)1_청계천_마장로39길 33   불법주정차  37.568470  127.043671
# 1090  성동구        P015_(고정1)1_도선사거리_고산자로 330   불법주정차  37.569138  127.037521
# 1091  성동구  P080_(고정3)4_텐즈힐2단지 아파트_상왕십리동2-19   불법주정차  37.570282  127.026497
# 1092  성동구       P016_(고정2)3_제2마장교_마장로35길 76   불법주정차  37.570602  127.042519
# 1093  성동구         P075_(고정1)9_삼공빌딩_청계천로 422   불법주정차  37.571037  127.023537
#
#       CCTV 수량       수정 일시
# 991         1  2021-12-07
# 992         1  2021-12-07
# 993         1  2021-12-07
# 994         1  2021-12-07
# 995         1  2021-12-07
# ...       ...         ...
# 1089        1  2021-12-07
# 1090        1  2021-12-07
# 1091        1  2021-12-07
# 1092        1  2021-12-07
# 1093        1  2021-12-07
#
# [103 rows x 7 columns]

# %%
# 인덱스 재지정
df_car.reset_index(drop=True, inplace=True)
df_car
# Out:
#      자치구                             안심 주소 CCTV 용도         위도          경도  \
# 0    성동구       P061_(고정4)7_천지인한의원_성덕정길 106   불법주정차  37.537220  127.055290
# 1    성동구    P035_(고정3)3_성수119안전센터_뚝섬로17길 3   불법주정차  37.537746  127.059616
# 2    성동구          P058_(고정3)4_선출빌딩_성덕정길 75   불법주정차  37.538063  127.051666
# 3    성동구         P062_(고정4)7_성원중학교_뚝섬로 400   불법주정차  37.538720  127.054907
# 4    성동구           P044_(회전)_성수동2가 혜미슈퍼 주변   불법주정차  37.541283  127.059441
# ..   ...                               ...     ...        ...         ...
# 98   성동구         P071_(고정2)1_청계천_마장로39길 33   불법주정차  37.568470  127.043671
# 99   성동구        P015_(고정1)1_도선사거리_고산자로 330   불법주정차  37.569138  127.037521
# 100  성동구  P080_(고정3)4_텐즈힐2단지 아파트_상왕십리동2-19   불법주정차  37.570282  127.026497
# 101  성동구       P016_(고정2)3_제2마장교_마장로35길 76   불법주정차  37.570602  127.042519
# 102  성동구         P075_(고정1)9_삼공빌딩_청계천로 422   불법주정차  37.571037  127.023537
#
#      CCTV 수량       수정 일시
# 0          1  2021-12-07
# 1          1  2021-12-07
# 2          1  2021-12-07
# 3          1  2021-12-07
# 4          1  2021-12-07
# ..       ...         ...
# 98         1  2021-12-07
# 99         1  2021-12-07
# 100        1  2021-12-07
# 101        1  2021-12-07
# 102        1  2021-12-07
#
# [103 rows x 7 columns]

# %%
import folium

m = folium.Map(location = [37.5544988, 127.0404364], zoom_start = 15, tiles = 'cartodb positron')

for i in range(len(df_car)):
  folium.Marker(location = [df_car.위도[i], df_car.경도[i] ],
                icon = folium.Icon(color = 'red', icon = 'search'),
                popup = df_car['안심 주소'][i]
                ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8f4be5025f837a409787e1bd3082b95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8f4be5025f837a409787e1bd3082b95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a8f4be5025f837a409787e1bd3082b95 = L.map(
#                 &quot;map_a8f4be5025f837a409787e1bd3082b95&quot;,
#                 {
#                     center: [37.5544988, 127.0404364],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48b9257b31bbf6c61432a4521aa9c841 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8f4be5025f837a409787e1bd3082b95);
#
#
#             var marker_ea3bda8e644dbf3c88538cc271ac50eb = L.marker(
#                 [37.53722, 127.0552902],
#                 {}
#             ).addTo(map_a8f4be5025f837a409787e1bd3082b95);
#
#
#             var icon_1b845dc4f032a4e6ced846aaebe89e75 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea3bda8e644dbf3c88538cc271ac50eb.setIcon(icon_1b845dc4f032a4e6ced846aaebe89e75);
#
#
#         var popup_de427019fda81deb4b0b89975963b7cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_99d92879bf8109110b939319505525f2 = $(`&lt;div id=&quot;html_99d92879bf8109110b939319505525f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P061_(고정4)7_천지인한의원_성덕정길 106&lt;/div&gt;`)[0];
#             popup_de427019fda81deb4b0b89975963b7cb.setContent(html_99d92879bf8109110b939319505525f2);
#
#
#         marker_ea3bda8e644dbf3c88538cc271ac50eb.bindPopup(popup_de427019fda81deb4b0b89975963b7cb)
#         ;
#
#
#
#
#             var marker_dbaf6f219e140bb21d04627529262f5c = L.marker(
#                 [37.53774643, 127.0596161],
#                 {}
#             ).addTo(map_a8f4be5025f837a409787e1bd3082b95);
#
#
#             var icon_70555bf25e23ed4bb6a6dfa3574d82d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dbaf6f219e140bb21d04627529262f5c.setIcon(icon_70555bf25e23ed4bb6a6dfa3574d82d8);
#
#
#         var popup_f82d1b3140270c14fdbf1bcee5971dbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f6734a130b90215ca398e753337da5e4 = $(`&lt;div id=&quot;html_f6734a130b90215ca398e753337da5e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P035_(고정3)3_성수119안전센터_뚝섬로17길 3&lt;/div&gt;`)[0];
#             popup_f82d1b3140270c14fdbf1bcee5971dbe.setContent(html_f6734a130b90215ca398e753337da5e4);
#
#
#         marker_dbaf6f219e140bb21d04627529262f5c.bindPopup(popup_f82d1b3140270c14fdbf1bcee5971dbe)
#         ;
#
#
#
#
#             var marker_52c9e3e6145186f2092815d8ab6242ce = L.marker(
#                 [37.53806305, 127.0516663],
#                 {}
#             ).addTo(map_a8f4be5025f837a409787e1bd3082b95);
#
#
#             var icon_f7c479860fb4b744dd35046269d5d347 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52c9e3e6145186f2092815d8ab6242ce.setIcon(icon_f7c479860fb4b744dd35046269d5d347);
#
#
#         var popup_b590508e13d84d646274a303032ea8ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_90e02db0460a94a26b758e73f66f2bec = $(`&lt;div id=&quot;html_90e02db0460a94a26b758e73f66f2bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P058_(고정3)4_선출빌딩_성덕정길 75&lt;/div&gt;`)[0];
#             popup_b590508e13d84d646274a303032ea8ba.setContent(html_90e02db0460a94a26b758e73f66f2bec);
#
#
#         marker_52c9e3e6145186f2092815d8ab6242ce.bindPopup(popup_b590508e13d84d646274a303032ea8ba)
#         ;
#
#
#
#
#             var marker_c64f247497f075165025eb44bc8a98f5 = L.marker(
#                 [37.53871972, 127.0549075],
#                 {}
#             ).addTo(map_a8f4be5025f837a409787e1bd3082b95);
#
#
#             var icon_c8e99c7c2ce430c143a4cb7772fbf6b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;search&quot;, &quot;iconColor&quot;: &quot;white&q

# %%
fin
